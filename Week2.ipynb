# %% [markdown]
# <a href="https://colab.research.google.com/github/Auful01/PCVK/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype = np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color = (0,255,0), thickness = 10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color = (0,0,255), thickness = 15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center = (100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace = font, fontScale =4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype = np.int32)
plt.imshow(black_img)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype = np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
# black_img = np.zeros(shape=(512,512,3), dtype = np.int16)
plt.imshow(black_img2 )

# %%
img6 = img3
# cv.imshow('B-RGB', img6)
cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_COLOR)
plt.imshow(img6)

# %%
images = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# RED GREEN CHANNEL
imgB = images
imgB[:, :, 2] = 0


plt.imshow(imgB)

# %%
images2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# GREEN BLUE CHANNEL
imgGB =images2
imgGB[:,:,0] = 0

plt.imshow(imgGB)

# %%
# images3[(10,100), (10,100)]

# %%
plt.imshow(images3[10:100,10:100])

# %%
plt.imshow(images3[5:30,0:images3.shape[1],2])

# %%
images3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_gray2 = cv.resize(cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE), (720,1440)) 
f, axarr = plt.subplots(2,3)
axarr[0,0].imshow(images3[:,:,1])
axarr[0,1].imshow(images3[:,:,2])
axarr[1,0].imshow(images3[:,:,0])
axarr[1,1].imshow(images3)
axarr[1,2].imshow(img_gray2, cmap='magma')
# plt.imshow(images3)

# %%
import random

images10 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_COLOR)
for x in range (5):
  # print(random.randrange(0, images10.shape[0],3))
  cv.rectangle(images10,pt1=(random.randrange(0, images10.shape[0], 10),random.randrange(0,images10.shape[1], 10)), pt2=(random.randrange(0,images10.shape[0], 10),random.randrange(0,images10.shape[1], 10)), color=(random.randrange(0,255,15),random.randrange(0,255,15),random.randrange(0,255,15)), thickness=8)
  plt.imshow(cv.cvtColor(images10,cv.COLOR_BGR2RGB))

# %%
plt.imshow(cv.flip(images3,0))

# %%
images5 = images3
cv.rectangle(images5,pt1=(300,90), pt2=(500,250), color=(0,255,0), thickness=8)
cv.circle(images5,center=(400,180), radius=100, color=(255,0,0), thickness=8)
plt.imshow(images5)

# %%
images6 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
newImg = cv.cvtColor(images6, cv.COLOR_BGR2RGB)
blue = newImg
blue[:,:,[0,1]]=0
cv.rectangle(blue,pt1=(0,500), pt2=(150,images5.shape[1]), color=(255,255,255), thickness=8)
plt.imshow(blue)
